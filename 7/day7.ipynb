# %%
import copy
import re

# %%
class Worker:
    def __init__(self, n):
        self.n = n
        self.task = None
        self.timedone = 0

    def __repr__(self):
        return "Worker(n=%d task=%s timedone=%s)" % (self.n, self.task, self.timedone)

class NodeList:
    pattern = re.compile(r"""Step (.+) must be finished before step (.+) can begin.""")
    
    def __init__(self):
        self.parents  = dict()
        self.children = dict()
    
    def add_constraint(self, p, c):
        if p not in self.children:
            self.children[p] = set()
        if c not in self.children:
            self.children[c] = set()
        self.children[p].add(c)
        
        if c not in self.parents:
            self.parents[c] = set()
        if p not in self.parents:
            self.parents[p] = set()
        self.parents[c].add(p)
    
    def pprint(self):
        print("children")
        for p, c in self.children.items():
            print("%s -> %s" % (p, ",".join(sorted(c))))
        print("parents")
        for c, p in self.parents.items():
            print("%s -> %s" % (c, ",".join(sorted(p))))
    
    def graphviz(self):
        print("digraph G {")
        for p, children in self.children.items():
            for c in children:
                print("%s -> %s" % (p, c))
        print("}")
    
    def head_nodes(self):
        head_nodes = []
        for c, p in self.parents.items():
            if not p:
                head_nodes.append(c)
        return head_nodes
    
    def resolve(self):
        parents = copy.deepcopy(self.parents)
        visited = set()
        visitedorder = []
        nodes = self.head_nodes()
        
        while nodes:
            # always grab first in alphabetical order among nodes
            nodes.sort()
            nodes.reverse()
            node = nodes.pop()
            
            # add to visited
            visited.add(node)
            visitedorder.append(node)
            
            # clear node from parent lists
            for i in parents:
                if node in parents[i]: 
                    parents[i].remove(node)
                    
            # add children of current that are available to nodes
            for c in self.children[node]:
                if not parents[c] and c not in visited:
                    nodes.append(c)
                    
        # no more nodes, return result
        return "".join(visitedorder)
    
    def workerstate(self, workers):
        out = []
        for w in workers:
            if w.task == None:
                out.append(".")
            else:
                out.append(w.task)
        return "".join(out)

    def process(self, nwork, delay=0, verbose=False):
        t = -1
        parents = copy.deepcopy(self.parents)
        visited = set()
        visitedorder = []
        avail = self.head_nodes()
        workers = []
        working = set()
        for i in range(nwork):
            workers.append(Worker(i))
        
        while avail or working:
            t += 1
            # clear finished workers first
            for w in workers:
                if t >= timedone and w.task != None:
                    visited.add(w.task)
                    visitedorder.append(w.task)
                    working.remove(w.task)
                        
                    for i in parents:
                        if w.task in parents[i]: 
                            parents[i].remove(w.task)
                                          
                    for c in self.children[w.task]:
                        if not parents[c] and c not in visited:
                            avail.append(c)
                                
                    w.task = None
                    w.timedone = 0
                
            for w in workers:
                if t >= w.timedone:                    
                    if avail:
                        avail.sort()
                        avail.reverse()
                        node = avail.pop()
            
                        # add to working
                        working.add(node)
                        w.task = node
                        w.timedone = t + ord(node) - ord('A') + 1 + delay
            if verbose:
                print("%4d %s %s" % (t, self.workerstate(workers), "".join(visitedorder)))

        return t
    
    @staticmethod
    def from_file(filename):
        nl = NodeList()
        with open(filename, "r") as fh:
            for l in fh:
                #print(l)
                m = NodeList.pattern.match(l.rstrip())
                if m:
                    nl.add_constraint(m.group(1), m.group(2))
        return nl

test = NodeList.from_file("test.txt")
#test.resolve()
test.process(2, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-13bda7eda57b> in <module>()
#     148 test = NodeList.from_file("test.txt")
#     149 #test.resolve()
# --> 150 test.process(2, verbose=True)
#
# <ipython-input-111-13bda7eda57b> in process(self, nwork, delay, verbose)
#     103             # clear finished workers first
#     104             for w in workers:
# --> 105                 if t >= timedone and w.task != None:
#     106                     visited.add(w.task)
#     107                     visitedorder.append(w.task)
#
# NameError: name 'timedone' is not defined

# %%
input = NodeList.from_file("input.txt")
#input.resolve()
input.process(5, delay=60, verbose=True)
# Out:
#    0 GOS..
#    1 GOS..
#    2 GOS..
#    3 GOS..
#    4 GOS..
#    5 GOS..
#    6 GOS..
#    7 GOS..
#    8 GOS..
#    9 GOS..
#   10 GOS..
#   11 GOS..
#   12 GOS..
#   13 GOS..
#   14 GOS..
#   15 GOS..
#   16 GOS..
#   17 GOS..
#   18 GOS..
#   19 GOS..
#   20 GOS..
#   21 GOS..
#   22 GOS..
#   23 GOS..
#   24 GOS..
#   25 GOS..
#   26 GOS..
#   27 GOS..
#   28 GOS..
#   29 GOS..
#   30 GOS..
#   31 GOS..
#   32 GOS..
#   33 GOS..
#   34 GOS..
#   35 GOS..
#   36 GOS..
#   37 GOS..
#   38 GOS..
#   39 GOS..
#   40 GOS..
#   41 GOS..
#   42 GOS..
#   43 GOS..
#   44 GOS..
#   45 GOS..
#   46 GOS..
#   47 GOS..
#   48 GOS..
#   49 GOS..
#   50 GOS..
#   51 GOS..
#   52 GOS..
#   53 GOS..
#   54 GOS..
#   55 GOS..
#   56 GOS..
#   57 GOS..
#   58 GOS..
#   59 GOS..
#   60 GOS..
#   61 GOS..
#   62 GOS..
#   63 GOS..
#   64 GOS..
#   65 GOS..
#   66 GOS..
#   67 DOSUX G
#   68 DOSUX G
#   69 DOSUX G
#   70 DOSUX G
#   71 DOSUX G
#   72 DOSUX G
#   73 DOSUX G
#   74 DOSUX G
#   75 D.SUX GO
#   76 D.SUX GO
#   77 D.SUX GO
#   78 D.SUX GO
#   79 D..UX GOS
#   80 D..UX GOS
#   81 D..UX GOS
#   82 D..UX GOS
#   83 D..UX GOS
#   84 D..UX GOS
#   85 D..UX GOS
#   86 D..UX GOS
#   87 D..UX GOS
#   88 D..UX GOS
#   89 D..UX GOS
#   90 D..UX GOS
#   91 D..UX GOS
#   92 D..UX GOS
#   93 D..UX GOS
#   94 D..UX GOS
#   95 D..UX GOS
#   96 D..UX GOS
#   97 D..UX GOS
#   98 D..UX GOS
#   99 D..UX GOS
#  100 D..UX GOS
#  101 D..UX GOS
#  102 D..UX GOS
#  103 D..UX GOS
#  104 D..UX GOS
#  105 D..UX GOS
#  106 D..UX GOS
#  107 D..UX GOS
#  108 D..UX GOS
#  109 D..UX GOS
#  110 D..UX GOS
#  111 D..UX GOS
#  112 D..UX GOS
#  113 D..UX GOS
#  114 D..UX GOS
#  115 D..UX GOS
#  116 D..UX GOS
#  117 D..UX GOS
#  118 D..UX GOS
#  119 D..UX GOS
#  120 D..UX GOS
#  121 D..UX GOS
#  122 D..UX GOS
#  123 D..UX GOS
#  124 D..UX GOS
#  125 D..UX GOS
#  126 D..UX GOS
#  127 D..UX GOS
#  128 D..UX GOS
#  129 D..UX GOS
#  130 D..UX GOS
#  131 H..UX GOSD
#  132 H..UX GOSD
#  133 H..UX GOSD
#  134 H..UX GOSD
#  135 H..UX GOSD
#  136 H..UX GOSD
#  137 H..UX GOSD
#  138 H..UX GOSD
#  139 H..UX GOSD
#  140 H..UX GOSD
#  141 H..UX GOSD
#  142 H..UX GOSD
#  143 H..UX GOSD
#  144 H..UX GOSD
#  145 H..UX GOSD
#  146 H..UX GOSD
#  147 H..UX GOSD
#  148 H...X GOSDU
#  149 H...X GOSDU
#  150 H...X GOSDU
#  151 H...A GOSDUX
#  152 H...A GOSDUX
#  153 H...A GOSDUX
#  154 H...A GOSDUX
#  155 H...A GOSDUX
#  156 H...A GOSDUX
#  157 H...A GOSDUX
#  158 H...A GOSDUX
#  159 H...A GOSDUX
#  160 H...A GOSDUX
#  161 H...A GOSDUX
#  162 H...A GOSDUX
#  163 H...A GOSDUX
#  164 H...A GOSDUX
#  165 H...A GOSDUX
#  166 H...A GOSDUX
#  167 H...A GOSDUX
#  168 H...A GOSDUX
#  169 H...A GOSDUX
#  170 H...A GOSDUX
#  171 H...A GOSDUX
#  172 H...A GOSDUX
#  173 H...A GOSDUX
#  174 H...A GOSDUX
#  175 H...A GOSDUX
#  176 H...A GOSDUX
#  177 H...A GOSDUX
#  178 H...A GOSDUX
#  179 H...A GOSDUX
#  180 H...A GOSDUX
#  181 H...A GOSDUX
#  182 H...A GOSDUX
#  183 H...A GOSDUX
#  184 H...A GOSDUX
#  185 H...A GOSDUX
#  186 H...A GOSDUX
#  187 H...A GOSDUX
#  188 H...A GOSDUX
#  189 H...A GOSDUX
#  190 H...A GOSDUX
#  191 H...A GOSDUX
#  192 H...A GOSDUX
#  193 H...A GOSDUX
#  194 H...A GOSDUX
#  195 H...A GOSDUX
#  196 H...A GOSDUX
#  197 H...A GOSDUX
#  198 H...A GOSDUX
#  199 ....A GOSDUXH
#  200 ....A GOSDUXH
#  201 ....A GOSDUXH
#  202 ....A GOSDUXH
#  203 ....A GOSDUXH
#  204 ....A GOSDUXH
#  205 ....A GOSDUXH
#  206 ....A GOSDUXH
#  207 ....A GOSDUXH
#  208 ....A GOSDUXH
#  209 ....A GOSDUXH
#  210 ....A GOSDUXH
#  211 ....A GOSDUXH
#  212 ....C GOSDUXHA
#  213 IMR.C GOSDUXHA
#  214 IMR.C GOSDUXHA
#  215 IMR.C GOSDUXHA
#  216 IMR.C GOSDUXHA
#  217 IMR.C GOSDUXHA
#  218 IMR.C GOSDUXHA
#  219 IMR.C GOSDUXHA
#  220 IMR.C GOSDUXHA
#  221 IMR.C GOSDUXHA
#  222 IMR.C GOSDUXHA
#  223 IMR.C GOSDUXHA
#  224 IMR.C GOSDUXHA
#  225 IMR.C GOSDUXHA
#  226 IMR.C GOSDUXHA
#  227 IMR.C GOSDUXHA
#  228 IMR.C GOSDUXHA
#  229 IMR.C GOSDUXHA
#  230 IMR.C GOSDUXHA
#  231 IMR.C GOSDUXHA
#  232 IMR.C GOSDUXHA
#  233 IMR.C GOSDUXHA
#  234 IMR.C GOSDUXHA
#  235 IMR.C GOSDUXHA
#  236 IMR.C GOSDUXHA
#  237 IMR.C GOSDUXHA
#  238 IMR.C GOSDUXHA
#  239 IMR.C GOSDUXHA
#  240 IMR.C GOSDUXHA
#  241 IMR.C GOSDUXHA
#  242 IMR.C GOSDUXHA
#  243 IMR.C GOSDUXHA
#  244 IMR.C GOSDUXHA
#  245 IMR.C GOSDUXHA
#  246 IMR.C GOSDUXHA
#  247 IMR.C GOSDUXHA
#  248 IMR.C GOSDUXHA
#  249 IMR.C GOSDUXHA
#  250 IMR.C GOSDUXHA
#  251 IMR.C GOSDUXHA
#  252 IMR.C GOSDUXHA
#  253 IMR.C GOSDUXHA
#  254 IMR.C GOSDUXHA
#  255 IMR.C GOSDUXHA
#  256 IMR.C GOSDUXHA
#  257 IMR.C GOSDUXHA
#  258 IMR.C GOSDUXHA
#  259 IMR.C GOSDUXHA
#  260 IMR.C GOSDUXHA
#  261 IMR.C GOSDUXHA
#  262 IMR.C GOSDUXHA
#  263 IMR.C GOSDUXHA
#  264 IMR.C GOSDUXHA
#  265 IMR.C GOSDUXHA
#  266 IMR.C GOSDUXHA
#  267 IMR.C GOSDUXHA
#  268 IMR.C GOSDUXHA
#  269 IMR.C GOSDUXHA
#  270 IMR.C GOSDUXHA
#  271 IMR.C GOSDUXHA
#  272 IMR.C GOSDUXHA
#  273 IMR.C GOSDUXHA
#  274 IMR.C GOSDUXHA
#  275 IMR.T GOSDUXHAC
#  276 IMR.T GOSDUXHAC
#  277 IMR.T GOSDUXHAC
#  278 IMR.T GOSDUXHAC
#  279 IMR.T GOSDUXHAC
#  280 IMR.T GOSDUXHAC
#  281 IMR.T GOSDUXHAC
#  282 WMR.T GOSDUXHACI
#  283 WMR.T GOSDUXHACI
#  284 WMR.T GOSDUXHACI
#  285 WMR.T GOSDUXHACI
#  286 W.R.T GOSDUXHACIM
#  287 W.R.T GOSDUXHACIM
#  288 W.R.T GOSDUXHACIM
#  289 W.R.T GOSDUXHACIM
#  290 W.R.T GOSDUXHACIM
#  291 W...T GOSDUXHACIMR
#  292 W...T GOSDUXHACIMR
#  293 W...T GOSDUXHACIMR
#  294 W...T GOSDUXHACIMR
#  295 W...T GOSDUXHACIMR
#  296 W...T GOSDUXHACIMR
#  297 W...T GOSDUXHACIMR
#  298 W...T GOSDUXHACIMR
#  299 W...T GOSDUXHACIMR
#  300 W...T GOSDUXHACIMR
#  301 W...T GOSDUXHACIMR
#  302 W...T GOSDUXHACIMR
#  303 W...T GOSDUXHACIMR
#  304 W...T GOSDUXHACIMR
#  305 W...T GOSDUXHACIMR
#  306 W...T GOSDUXHACIMR
#  307 W...T GOSDUXHACIMR
#  308 W...T GOSDUXHACIMR
#  309 W...T GOSDUXHACIMR
#  310 W...T GOSDUXHACIMR
#  311 W...T GOSDUXHACIMR
#  312 W...T GOSDUXHACIMR
#  313 W...T GOSDUXHACIMR
#  314 W...T GOSDUXHACIMR
#  315 W...T GOSDUXHACIMR
#  316 W...T GOSDUXHACIMR
#  317 W...T GOSDUXHACIMR
#  318 W...T GOSDUXHACIMR
#  319 W...T GOSDUXHACIMR
#  320 W...T GOSDUXHACIMR
#  321 W...T GOSDUXHACIMR
#  322 W...T GOSDUXHACIMR
#  323 W...T GOSDUXHACIMR
#  324 W...T GOSDUXHACIMR
#  325 W...T GOSDUXHACIMR
#  326 W...T GOSDUXHACIMR
#  327 W...T GOSDUXHACIMR
#  328 W...T GOSDUXHACIMR
#  329 W...T GOSDUXHACIMR
#  330 W...T GOSDUXHACIMR
#  331 W...T GOSDUXHACIMR
#  332 W...T GOSDUXHACIMR
#  333 W...T GOSDUXHACIMR
#  334 W...T GOSDUXHACIMR
#  335 W...T GOSDUXHACIMR
#  336 W...T GOSDUXHACIMR
#  337 W...T GOSDUXHACIMR
#  338 W...T GOSDUXHACIMR
#  339 W...T GOSDUXHACIMR
#  340 W...T GOSDUXHACIMR
#  341 W...T GOSDUXHACIMR
#  342 W...T GOSDUXHACIMR
#  343 W...T GOSDUXHACIMR
#  344 W...T GOSDUXHACIMR
#  345 W...T GOSDUXHACIMR
#  346 W...T GOSDUXHACIMR
#  347 W...T GOSDUXHACIMR
#  348 W...T GOSDUXHACIMR
#  349 W...T GOSDUXHACIMR
#  350 W...T GOSDUXHACIMR
#  351 W...T GOSDUXHACIMR
#  352 W...T GOSDUXHACIMR
#  353 W...T GOSDUXHACIMR
#  354 W...T GOSDUXHACIMR
#  355 W...P GOSDUXHACIMRT
#  356 W...P GOSDUXHACIMRT
#  357 W...P GOSDUXHACIMRT
#  358 W...P GOSDUXHACIMRT
#  359 W...P GOSDUXHACIMRT
#  360 W...P GOSDUXHACIMRT
#  361 W...P GOSDUXHACIMRT
#  362 W...P GOSDUXHACIMRT
#  363 W...P GOSDUXHACIMRT
#  364 W...P GOSDUXHACIMRT
#  365 ....P GOSDUXHACIMRTW
#  366 ....P GOSDUXHACIMRTW
#  367 ....P GOSDUXHACIMRTW
#  368 ....P GOSDUXHACIMRTW
#  369 ....P GOSDUXHACIMRTW
#  370 ....P GOSDUXHACIMRTW
#  371 ....P GOSDUXHACIMRTW
#  372 ....P GOSDUXHACIMRTW
#  373 ....P GOSDUXHACIMRTW
#  374 ....P GOSDUXHACIMRTW
#  375 ....P GOSDUXHACIMRTW
#  376 ....P GOSDUXHACIMRTW
#  377 ....P GOSDUXHACIMRTW
#  378 ....P GOSDUXHACIMRTW
#  448 Y...N GOSDUXHACIMRTWP
#  449 Y...N GOSDUXHACIMRTWP
#  450 Y...N GOSDUXHACIMRTWP
#  451 Y...N GOSDUXHACIMRTWP
#  452 Y...N GOSDUXHACIMRTWP
#  453 Y...N GOSDUXHACIMRTWP
#  454 Y...N GOSDUXHACIMRTWP
#  455 Y...N GOSDUXHACIMRTWP
#  456 Y...N GOSDUXHACIMRTWP
#  457 Y...N GOSDUXHACIMRTWP
#  458 Y...N GOSDUXHACIMRTWP
#  459 Y...N GOSDUXHACIMRTWP
#  460 Y...N GOSDUXHACIMRTWP
#  461 Y...N GOSDUXHACIMRTWP
#  462 Y...N GOSDUXHACIMRTWP
#  463 Y...N GOSDUXHACIMRTWP
#  464 Y...N GOSDUXHACIMRTWP
#  465 Y...N GOSDUXHACIMRTWP
#  466 Y...N GOSDUXHACIMRTWP
#  467 Y...N GOSDUXHACIMRTWP
#  468 Y...N GOSDUXHACIMRTWP
#  469 Y...N GOSDUXHACIMRTWP
#  470 Y...N GOSDUXHACIMRTWP
#  471 Y...N GOSDUXHACIMRTWP
#  472 Y...N GOSDUXHACIMRTWP
#  473 Y...N GOSDUXHACIMRTWP
#  474 Y...N GOSDUXHACIMRTWP
#  475 Y...N GOSDUXHACIMRTWP
#  476 Y...N GOSDUXHACIMRTWP
#  477 Y...N GOSDUXHACIMRTWP
#  478 Y...N GOSDUXHACIMRTWP
#  479 Y...N GOSDUXHACIMRTWP
#  480 Y...N GOSDUXHACIMRTWP
#  481 Y...N GOSDUXHACIMRTWP
#  482 Y...N GOSDUXHACIMRTWP
#  483 Y...N GOSDUXHACIMRTWP
#  484 Y...N GOSDUXHACIMRTWP
#  485 Y...N GOSDUXHACIMRTWP
#  486 Y...N GOSDUXHACIMRTWP
#  487 Y...N GOSDUXHACIMRTWP
#  488 Y...N GOSDUXHACIMRTWP
#  489 Y...N GOSDUXHACIMRTWP
#  490 Y...N GOSDUXHACIMRTWP
#  491 Y...N GOSDUXHACIMRTWP
#  492 Y...N GOSDUXHACIMRTWP
#  493 Y...N GOSDUXHACIMRTWP
#  494 Y...N GOSDUXHACIMRTWP
#  495 Y...N GOSDUXHACIMRTWP
#  496 Y...N GOSDUXHACIMRTWP
#  497 Y...N GOSDUXHACIMRTWP
#  498 Y...N GOSDUXHACIMRTWP
#  499 Y...N GOSDUXHACIMRTWP
#  500 Y...N GOSDUXHACIMRTWP
#  501 Y...N GOSDUXHACIMRTWP
#  502 Y...N GOSDUXHACIMRTWP
#  503 Y...N GOSDUXHACIMRTWP
#  504 Y...N GOSDUXHACIMRTWP
#  505 Y.... GOSDUXHACIMRTWPN
#  506 Y.... GOSDUXHACIMRTWPN
#  507 Y.... GOSDUXHACIMRTWPN
#  508 Y.... GOSDUXHACIMRTWPN
#  509 Y.... GOSDUXHACIMRTWPN
#  510 Y.... GOSDUXHACIMRTWPN
#  511 Y.... GOSDUXHACIMRTWPN
#  512 Y.... GOSDUXHACIMRTWPN
#  513 Y.... GOSDUXHACIMRTWPN
#  514 Y.... GOSDUXHACIMRTWPN
#  515 Y.... GOSDUXHACIMRTWPN
#  516 Y.... GOSDUXHACIMRTWPN
#  517 J.... GOSDUXHACIMRTWPNY
#  518 J.... GOSDUXHACIMRTWPNY
#  519 J.... GOSDUXHACIMRTWPNY
#  520 J.... GOSDUXHACIMRTWPNY
#  521 J.... GOSDUXHACIMRTWPNY
#  522 J.... GOSDUXHACIMRTWPNY
#  523 J.... GOSDUXHACIMRTWPNY
#  524 J.... GOSDUXHACIMRTWPNY
#  525 J.... GOSDUXHACIMRTWPNY
#  526 J.... GOSDUXHACIMRTWPNY
#  527 J.... GOSDUXHACIMRTWPNY
#  528 J.... GOSDUXHACIMRTWPNY
#  529 J.... GOSDUXHACIMRTWPNY
#  530 J.... GOSDUXHACIMRTWPNY
#  531 J.... GOSDUXHACIMRTWPNY
#  532 J.... GOSDUXHACIMRTWPNY
#  533 J.... GOSDUXHACIMRTWPNY
#  534 J.... GOSDUXHACIMRTWPNY
#  535 J.... GOSDUXHACIMRTWPNY
#  536 J.... GOSDUXHACIMRTWPNY
#  537 J.... GOSDUXHACIMRTWPNY
#  538 J.... GOSDUXHACIMRTWPNY
#  539 J.... GOSDUXHACIMRTWPNY
#  540 J.... GOSDUXHACIMRTWPNY
#  541 J.... GOSDUXHACIMRTWPNY
#  542 J.... GOSDUXHACIMRTWPNY
#  543 J.... GOSDUXHACIMRTWPNY
#  544 J.... GOSDUXHACIMRTWPNY
#  545 J.... GOSDUXHACIMRTWPNY
#  546 J.... GOSDUXHACIMRTWPNY
#  547 J.... GOSDUXHACIMRTWPNY
#  548 J.... GOSDUXHACIMRTWPNY
#  549 J.... GOSDUXHACIMRTWPNY
#  550 J.... GOSDUXHACIMRTWPNY
#  551 J.... GOSDUXHACIMRTWPNY
#  552 J.... GOSDUXHACIMRTWPNY
#  553 J.... GOSDUXHACIMRTWPNY
#  554 J.... GOSDUXHACIMRTWPNY
#  555 J.... GOSDUXHACIMRTWPNY
#  556 J.... GOSDUXHACIMRTWPNY
#  557 J.... GOSDUXHACIMRTWPNY
#  558 J.... GOSDUXHACIMRTWPNY
#  559 J.... GOSDUXHACIMRTWPNY
#  560 J.... GOSDUXHACIMRTWPNY
#  561 J.... GOSDUXHACIMRTWPNY
#  562 J.... GOSDUXHACIMRTWPNY
#  563 J.... GOSDUXHACIMRTWPNY
#  564 J.... GOSDUXHACIMRTWPNY
#  565 J.... GOSDUXHACIMRTWPNY
#  566 J.... GOSDUXHACIMRTWPNY
#  567 J.... GOSDUXHACIMRTWPNY
#  568 J.... GOSDUXHACIMRTWPNY
#  569 J.... GOSDUXHACIMRTWPNY
#  570 J.... GOSDUXHACIMRTWPNY
#  571 J.... GOSDUXHACIMRTWPNY
#  572 J.... GOSDUXHACIMRTWPNY
#  573 J.... GOSDUXHACIMRTWPNY
